# %% [markdown]
# <a href="https://colab.research.google.com/github/VannEdwin/money-methane-sql-python/blob/main/01_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

paths = [
    "data/raw",
    "data/processed",
    "notebooks",
    "sql",
    "src",
]
 for p in paths:
    os.makedirs(p, exist_ok=True)

  open("sql/schema.sql", "w").write("-- SQL schema goes here\n")
  open("src/db_utils.py", "w").write("# Database utilities will go here\n")
  open("README.md", "w").write("# Money & Methane (SQL + Python \n")
  open("requirements.txt", "w").write("pandas\nsqlalchemy\nmatplotlib\n")
