# %% [markdown]
# <a href="https://colab.research.google.com/github/VannEdwin/money-methane-sql-python/blob/main/notebooks/01_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from src.db_utils import initialize_db, load_dataframe, query
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1037847700.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 from src.db_utils import initialize_db, load_dataframe, query
#
# ModuleNotFoundError: No module named 'src'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
initialize_db()

# %%
aq = pd.read_csv("data/raw/air_quality_2015_2020.csv")
load_dataframe(aq, "air_quality")

# %%
query ("""
SELECT county_name, state, year, pm25
FROM air_quality
ORDER BY pm25 DESC
LIMIT 10;
""")
